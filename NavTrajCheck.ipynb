# %%
import numpy as np
import os as os
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras
import random as rand

import NavigationTrajectory as nt
import TFNNModels as NNM

# %% [markdown]
# #### Test Trained Model Trajectory

# %%
x = nt.NavigationTrajectory()
xx = NNM.TFNNModels()
# Out:
# Created navigation trajectory object
# Created NN Model Instance

# %%
learned_model1 = keras.models.load_model('model_vm1x')  # LOAD MODEL
learned_model2 = keras.models.load_model('model_vm1y')  # LOAD MODEL
learned_model3 = keras.models.load_model('model_vm2x')  # LOAD MODEL
learned_model4 = keras.models.load_model('model_vm2y')  # LOAD MODEL

# import data and trun into array
df_good_inp = pd.read_csv('Good_Input_Data.csv')  # import data
df_good_target = pd.read_csv('Good_Target_Data.csv')  # import data

input = np.asarray(df_good_inp)
real_target = np.asarray(df_good_target)

PredictedTarget = xx.PredictMidArray(learned_model1,learned_model2,learned_model3,learned_model4,input,100)
# Out:
# ...
# 4/4 [==============================] - 0s 4ms/step

# %%
index = rand.randint(0,100)
trajectory = x.Gen_MoveC2(input[:100],PredictedTarget,index,parts=5)
x.HitCheckPlot(input[index,4],input[index,5],.6,trajectory)
